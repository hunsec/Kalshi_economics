# %%
# Voer dit uit in een cel
# !pip install pandas requests
# !pip install fredapi Fred
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for Fred: filename=fred-3.1-py3-none-any.whl size=3740 sha256=5b6fc199f312df3f9fbf4647761defbf49759296377b7c6f193b24256308a68a
#   Stored in directory: c:\users\louis\appdata\local\pip\cache\wheels\3d\99\6d\d6737a627814048bbee46f6b7d56f1b75f5730787f59d6226a
# Successfully built Fred
# ...
#
#    ---------------------------------------- 2/2 [fredapi]
#
# ...

# %%
from fredapi import Fred
from datetime import datetime, timedelta
import pandas as pd

# 1. Initialize with your API key
# Get one at: https://fredaccount.stlouisfed.org/apikeys
fred = Fred(api_key='94318e235b2c36c1a3159affe94b3ffc')

# 2. Pull the monthly CPI (Seasonally Adjusted)
cpi_data = fred.get_series('CPIAUCSL')
# 3. Format as a clean DataFrame
df = pd.DataFrame(cpi_data, columns=['CPI_Value'])
df.index.name = 'Date'

# %%
# Export to Excel
file_name = "US_CPI_Historical_Data.xlsx"
df.to_excel(file_name)
print(f"Success! Data exported to {file_name}")
print(df.tail())
# Out:
# Success! Data exported to US_CPI_Historical_Data.xlsx
#             CPI_Value
# Date
# 2025-10-01        NaN
# 2025-11-01    325.063
# 2025-12-01    326.031
# 2026-01-01    326.588
# 2026-02-01    327.460
