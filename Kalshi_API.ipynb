# %%
import requests

# Get series information for KXECONSTATCORECPIYOY
url = "https://api.elections.kalshi.com/trade-api/v2/series/KXCPI"
response = requests.get(url)
series_data = response.json()

# Check if 'series' key exists before accessing its values
if 'series' in series_data:
    print(f"Series Title: {series_data['series']['title']}")
    print(f"Frequency: {series_data['series']['frequency']}")
    print(f"Category: {series_data['series']['category']}")
else:
    print(f"Error fetching series data: {series_data.get('error', 'Unknown error')}")
print(series_data)
# Out:
# Series Title: CPI
# Frequency: monthly
# Category: Economics
# {'series': {'additional_prohibitions': ['Persons who are employed by any of the Source Agencies are not permitted to trade on the Contract.', 'Persons who hold any material, non-public information on the Underlying are not permitted to trade on the Contract.'], 'category': 'Economics', 'contract_terms_url': 'https://kalshi-public-docs.s3.amazonaws.com/contract_terms/CPI.pdf', 'contract_url': 'https://kalshi-public-docs.s3.us-east-1.amazonaws.com/regulatory/product-certifications/CPI.pdf', 'fee_multiplier': 1, 'fee_type': 'quadratic_with_maker_fees', 'frequency': 'monthly', 'last_updated_ts': '2026-02-26T08:50:31.901806Z', 'settlement_sources': [{'name': 'Bureau of Labor Statistics', 'url': 'https://www.bls.gov/cpi/'}], 'tags': ['Inflation'], 'ticker': 'KXCPI', 'title': 'CPI'}}

# %%
# Get all markets for the KXECONSTATCORECPIYOY series (removing the status filter)
markets_url = f"https://api.elections.kalshi.com/trade-api/v2/markets?series_ticker=KXCPI"
markets_response = requests.get(markets_url)
markets_data = markets_response.json()

print(f"\nActive markets in KXECONSTATCORECPIYOY series:")
for market in markets_data['markets']:
    print(f"- {market['ticker']}: {market['title']}")
    print(f"  Event: {market['event_ticker']}")
    # Use .get() to safely access 'yes_price' and 'volume', providing 'N/A' if not present
    yes_price_display = f"{market.get('yes_price', 'N/A')}¢" if market.get('yes_price') is not None else 'N/A'
    volume_display = market.get('volume', 'N/A')
    print(f"  Yes Price: {yes_price_display} | Volume: {volume_display}")
    print()

# Get details for a specific event if you have its ticker
if markets_data['markets']:
    # Let's get details for the first market's event
    event_ticker = markets_data['markets'][0]['event_ticker']
    event_url = f"https://api.elections.kalshi.com/trade-api/v2/events/{event_ticker}"
    event_response = requests.get(event_url)
    event_data = event_response.json()

    print(f"Event Details:")
    print(f"Title: {event_data['event']['title']}")
    print(f"Category: {event_data['event']['category']}")
# Out:
# Active markets in KXECONSTATCORECPIYOY series:
# - KXCPI-26MAY-T1.0: Will CPI rise more than 1.0% in May 2026?
#   Event: KXCPI-26MAY
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAY-T0.9: Will CPI rise more than 0.9% in May 2026?
#   Event: KXCPI-26MAY
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAY-T0.8: Will CPI rise more than 0.8% in May 2026?
#   Event: KXCPI-26MAY
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAY-T0.7: Will CPI rise more than 0.7% in May 2026?
#   Event: KXCPI-26MAY
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAY-T0.6: Will CPI rise more than 0.6% in May 2026?
#   Event: KXCPI-26MAY
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26APR-T1.0: Will CPI rise more than 1.0% in April 2026?
#   Event: KXCPI-26APR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26APR-T0.9: Will CPI rise more than 0.9% in April 2026?
#   Event: KXCPI-26APR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26APR-T0.8: Will CPI rise more than 0.8% in April 2026?
#   Event: KXCPI-26APR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26APR-T0.7: Will CPI rise more than 0.7% in April 2026?
#   Event: KXCPI-26APR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26APR-T0.6: Will CPI rise more than 0.6% in April 2026?
#   Event: KXCPI-26APR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAR-T1.3: Will CPI rise more than 1.3% in March 2026?
#   Event: KXCPI-26MAR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAR-T1.2: Will CPI rise more than 1.2% in March 2026?
#   Event: KXCPI-26MAR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAR-T1.1: Will CPI rise more than 1.1% in March 2026?
#   Event: KXCPI-26MAR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAR-T1.0: Will CPI rise more than 1.0% in March 2026?
#   Event: KXCPI-26MAR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAR-T0.9: Will CPI rise more than 0.9% in March 2026?
#   Event: KXCPI-26MAR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAR-T0.8: Will CPI rise more than 0.8% in March 2026?
#   Event: KXCPI-26MAR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAR-T0.7: Will CPI rise more than 0.7% in March 2026?
#   Event: KXCPI-26MAR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAR-T0.6: Will CPI rise more than 0.6% in March 2026?
#   Event: KXCPI-26MAR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26NOV-T0.5: Will CPI rise more than 0.5% in November 2026?
#   Event: KXCPI-26NOV
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26NOV-T0.4: Will CPI rise more than 0.4% in November 2026?
#   Event: KXCPI-26NOV
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26NOV-T0.3: Will CPI rise more than 0.3% in November 2026?
#   Event: KXCPI-26NOV
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26NOV-T0.2: Will CPI rise more than 0.2% in November 2026?
#   Event: KXCPI-26NOV
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26NOV-T0.1: Will CPI rise more than 0.1% in November 2026?
#   Event: KXCPI-26NOV
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26NOV-T-0.1: Will CPI rise more than -0.1% in November 2026?
#   Event: KXCPI-26NOV
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26NOV-T0.0: Will CPI rise more than 0.0% in November 2026?
#   Event: KXCPI-26NOV
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26OCT-T0.5: Will CPI rise more than 0.5% in October 2026?
#   Event: KXCPI-26OCT
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26OCT-T0.4: Will CPI rise more than 0.4% in October 2026?
#   Event: KXCPI-26OCT
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26OCT-T0.3: Will CPI rise more than 0.3% in October 2026?
#   Event: KXCPI-26OCT
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26OCT-T0.2: Will CPI rise more than 0.2% in October 2026?
#   Event: KXCPI-26OCT
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26OCT-T0.1: Will CPI rise more than 0.1% in October 2026?
#   Event: KXCPI-26OCT
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26OCT-T-0.1: Will CPI rise more than -0.1% in October 2026?
#   Event: KXCPI-26OCT
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26OCT-T0.0: Will CPI rise more than 0.0% in October 2026?
#   Event: KXCPI-26OCT
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26SEP-T0.5: Will CPI rise more than 0.5% in September 2026?
#   Event: KXCPI-26SEP
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26SEP-T0.4: Will CPI rise more than 0.4% in September 2026?
#   Event: KXCPI-26SEP
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26SEP-T0.3: Will CPI rise more than 0.3% in September 2026?
#   Event: KXCPI-26SEP
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26SEP-T0.2: Will CPI rise more than 0.2% in September 2026?
#   Event: KXCPI-26SEP
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26SEP-T0.1: Will CPI rise more than 0.1% in September 2026?
#   Event: KXCPI-26SEP
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26SEP-T-0.1: Will CPI rise more than -0.1% in September 2026?
#   Event: KXCPI-26SEP
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26SEP-T0.0: Will CPI rise more than 0.0% in September 2026?
#   Event: KXCPI-26SEP
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26AUG-T0.5: Will CPI rise more than 0.5% in August 2026?
#   Event: KXCPI-26AUG
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26AUG-T0.4: Will CPI rise more than 0.4% in August 2026?
#   Event: KXCPI-26AUG
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26AUG-T0.3: Will CPI rise more than 0.3% in August 2026?
#   Event: KXCPI-26AUG
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26AUG-T0.2: Will CPI rise more than 0.2% in August 2026?
#   Event: KXCPI-26AUG
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26AUG-T0.1: Will CPI rise more than 0.1% in August 2026?
#   Event: KXCPI-26AUG
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26AUG-T-0.1: Will CPI rise more than -0.1% in August 2026?
#   Event: KXCPI-26AUG
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26AUG-T0.0: Will CPI rise more than 0.0% in August 2026?
#   Event: KXCPI-26AUG
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26JUL-T0.5: Will CPI rise more than 0.5% in July 2026?
#   Event: KXCPI-26JUL
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26JUL-T0.4: Will CPI rise more than 0.4% in July 2026?
#   Event: KXCPI-26JUL
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26JUL-T0.3: Will CPI rise more than 0.3% in July 2026?
#   Event: KXCPI-26JUL
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26JUL-T0.2: Will CPI rise more than 0.2% in July 2026?
#   Event: KXCPI-26JUL
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26JUL-T0.1: Will CPI rise more than 0.1% in July 2026?
#   Event: KXCPI-26JUL
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26JUL-T-0.1: Will CPI rise more than -0.1% in July 2026?
#   Event: KXCPI-26JUL
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26JUL-T0.0: Will CPI rise more than 0.0% in July 2026?
#   Event: KXCPI-26JUL
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26JUN-T0.5: Will CPI rise more than 0.5% in June 2026?
#   Event: KXCPI-26JUN
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26JUN-T0.4: Will CPI rise more than 0.4% in June 2026?
#   Event: KXCPI-26JUN
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26JUN-T0.3: Will CPI rise more than 0.3% in June 2026?
#   Event: KXCPI-26JUN
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26JUN-T0.2: Will CPI rise more than 0.2% in June 2026?
#   Event: KXCPI-26JUN
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26JUN-T0.1: Will CPI rise more than 0.1% in June 2026?
#   Event: KXCPI-26JUN
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26JUN-T-0.1: Will CPI rise more than -0.1% in June 2026?
#   Event: KXCPI-26JUN
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26JUN-T0.0: Will CPI rise more than 0.0% in June 2026?
#   Event: KXCPI-26JUN
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAY-T0.5: Will CPI rise more than 0.5% in May 2026?
#   Event: KXCPI-26MAY
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAY-T0.4: Will CPI rise more than 0.4% in May 2026?
#   Event: KXCPI-26MAY
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAY-T0.3: Will CPI rise more than 0.3% in May 2026?
#   Event: KXCPI-26MAY
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAY-T0.2: Will CPI rise more than 0.2% in May 2026?
#   Event: KXCPI-26MAY
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAY-T0.1: Will CPI rise more than 0.1% in May 2026?
#   Event: KXCPI-26MAY
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAY-T-0.1: Will CPI rise more than -0.1% in May 2026?
#   Event: KXCPI-26MAY
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAY-T0.0: Will CPI rise more than 0.0% in May 2026?
#   Event: KXCPI-26MAY
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26APR-T0.5: Will CPI rise more than 0.5% in April 2026?
#   Event: KXCPI-26APR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26APR-T0.4: Will CPI rise more than 0.4% in April 2026?
#   Event: KXCPI-26APR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26APR-T0.3: Will CPI rise more than 0.3% in April 2026?
#   Event: KXCPI-26APR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26APR-T0.2: Will CPI rise more than 0.2% in April 2026?
#   Event: KXCPI-26APR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26APR-T0.1: Will CPI rise more than 0.1% in April 2026?
#   Event: KXCPI-26APR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26APR-T-0.1: Will CPI rise more than -0.1% in April 2026?
#   Event: KXCPI-26APR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26APR-T0.0: Will CPI rise more than 0.0% in April 2026?
#   Event: KXCPI-26APR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAR-T0.5: Will CPI rise more than 0.5% in March 2026?
#   Event: KXCPI-26MAR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAR-T0.4: Will CPI rise more than 0.4% in March 2026?
#   Event: KXCPI-26MAR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAR-T0.3: Will CPI rise more than 0.3% in March 2026?
#   Event: KXCPI-26MAR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAR-T0.2: Will CPI rise more than 0.2% in March 2026?
#   Event: KXCPI-26MAR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAR-T0.1: Will CPI rise more than 0.1% in March 2026?
#   Event: KXCPI-26MAR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAR-T-0.1: Will CPI rise more than -0.1% in March 2026?
#   Event: KXCPI-26MAR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26MAR-T0.0: Will CPI rise more than 0.0% in March 2026?
#   Event: KXCPI-26MAR
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26FEB-T0.4: Will CPI rise more than 0.4% in February 2026?
#   Event: KXCPI-26FEB
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26FEB-T0.3: Will CPI rise more than 0.3% in February 2026?
#   Event: KXCPI-26FEB
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26FEB-T0.2: Will CPI rise more than 0.2% in February 2026?
#   Event: KXCPI-26FEB
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26FEB-T0.1: Will CPI rise more than 0.1% in February 2026?
#   Event: KXCPI-26FEB
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26FEB-T-0.1: Will CPI rise more than -0.1% in February 2026?
#   Event: KXCPI-26FEB
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26FEB-T0.0: Will CPI rise more than 0.0% in February 2026?
#   Event: KXCPI-26FEB
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26JAN-T0.4: Will CPI rise more than 0.4% in January 2026?
#   Event: KXCPI-26JAN
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26JAN-T0.3: Will CPI rise more than 0.3% in January 2026?
#   Event: KXCPI-26JAN
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26JAN-T0.2: Will CPI rise more than 0.2% in January 2026?
#   Event: KXCPI-26JAN
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26JAN-T0.1: Will CPI rise more than 0.1% in January 2026?
#   Event: KXCPI-26JAN
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26JAN-T-0.1: Will CPI rise more than -0.1% in January 2026?
#   Event: KXCPI-26JAN
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-26JAN-T0.0: Will CPI rise more than 0.0% in January 2026?
#   Event: KXCPI-26JAN
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-25DEC-T0.4: Will CPI rise more than 0.4% in December 2025?
#   Event: KXCPI-25DEC
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-25DEC-T0.3: Will CPI rise more than 0.3% in December 2025?
#   Event: KXCPI-25DEC
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-25DEC-T0.2: Will CPI rise more than 0.2% in December 2025?
#   Event: KXCPI-25DEC
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-25DEC-T0.1: Will CPI rise more than 0.1% in December 2025?
#   Event: KXCPI-25DEC
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-25DEC-T-0.1: Will CPI rise more than -0.1% in December 2025?
#   Event: KXCPI-25DEC
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-25DEC-T0.0: Will CPI rise more than 0.0% in December 2025?
#   Event: KXCPI-25DEC
#   Yes Price: N/A | Volume: N/A
#
# - KXCPI-25OCT-T0.4: Will CPI rise more than 0.4% in October 2025?
#   Event: KXCPI-25OCT
#   Yes Price: N/A | Volume: N/A
#
# Event Details:
# Title: CPI in May
# Category: Economics

# %%
import requests

# Get all active markets from Kalshi API for the KXCPI series
# This code is added to ensure 'markets_data' is defined when this cell is executed.
markets_url = "https://api.elections.kalshi.com/trade-api/v2/markets?series_ticker=KXCPI"
markets_response = requests.get(markets_url)
markets_data = markets_response.json()

# Get orderbook for all markets in the KXCPI series

if not markets_data['markets']:
    print("No markets found for the KXCPI series. Please ensure the series ticker is correct and markets exist.")
else:
    for market in markets_data['markets']:
        market_ticker = market['ticker']
        market_title = market['title'] # Get the market title

        # Safely get the expected CPI core percentage if available
        # This field might not exist in all market types, so using .get() is robust.
        expected_cpi_core = market.get('custom_strike', {}).get('Value', 'N/A')

        orderbook_url = f"https://api.elections.kalshi.com/trade-api/v2/markets/{market_ticker}/orderbook"

        orderbook_response = requests.get(orderbook_url)
        orderbook_data = orderbook_response.json()

        print(f"\n--- Orderbook for {market_ticker} ---")
        print(f"Market Title: {market_title}")
        print(f"Expected CPI Core: {expected_cpi_core}%") # Print the expected CPI core

        print("YES BIDS:")
        if 'yes_dollars' in orderbook_data['orderbook_fp'] and orderbook_data['orderbook_fp']['yes_dollars']:
            for bid in orderbook_data['orderbook_fp']['yes_dollars'][:5]:  # Show top 5
                print(f"  Price: {bid[0]}¢, Quantity: {bid[1]}")
        else:
            print("  No YES bids available.")

        print("\nNO BIDS:")
        if 'no_dollars' in orderbook_data['orderbook_fp'] and orderbook_data['orderbook_fp']['no_dollars']:
            for bid in orderbook_data['orderbook_fp']['no_dollars'][:5]:  # Show top 5
                print(f"  Price: {bid[0]}¢, Quantity: {bid[1]}")
        else:
            print("  No NO bids available.")
        print("-------------------------------------")
# Out:
# --- Orderbook for KXCPI-26MAY-T1.0 ---
# Market Title: Will CPI rise more than 1.0% in May 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 50.00
#   Price: 0.0900¢, Quantity: 75.00
#   Price: 0.1100¢, Quantity: 122.00
#   Price: 0.1600¢, Quantity: 55.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 650.00
#   Price: 0.0200¢, Quantity: 600.00
#   Price: 0.4500¢, Quantity: 2.00
#   Price: 0.4900¢, Quantity: 12.00
#   Price: 0.6600¢, Quantity: 4.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAY-T0.9 ---
# Market Title: Will CPI rise more than 0.9% in May 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 50.00
#   Price: 0.0300¢, Quantity: 1.00
#   Price: 0.1000¢, Quantity: 5.00
#   Price: 0.1100¢, Quantity: 5.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 50.00
#   Price: 0.0500¢, Quantity: 5.00
#   Price: 0.0600¢, Quantity: 135.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAY-T0.8 ---
# Market Title: Will CPI rise more than 0.8% in May 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 50.00
#   Price: 0.0300¢, Quantity: 1.00
#   Price: 0.1100¢, Quantity: 5.00
#   Price: 0.1700¢, Quantity: 36.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 850.00
#   Price: 0.0200¢, Quantity: 800.00
#   Price: 0.0300¢, Quantity: 100.00
#   Price: 0.0400¢, Quantity: 5.00
#   Price: 0.5500¢, Quantity: 36.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAY-T0.7 ---
# Market Title: Will CPI rise more than 0.7% in May 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 50.00
#   Price: 0.1200¢, Quantity: 2.00
#   Price: 0.1300¢, Quantity: 5.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 50.00
#   Price: 0.0300¢, Quantity: 5.00
#   Price: 0.0400¢, Quantity: 123.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAY-T0.6 ---
# Market Title: Will CPI rise more than 0.6% in May 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 50.00
#   Price: 0.0200¢, Quantity: 5.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 50.00
#   Price: 0.0300¢, Quantity: 5.00
#   Price: 0.0400¢, Quantity: 184.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26APR-T1.0 ---
# Market Title: Will CPI rise more than 1.0% in April 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 50.00
#   Price: 0.0200¢, Quantity: 5.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 50.00
#   Price: 0.1300¢, Quantity: 5.00
#   Price: 0.1400¢, Quantity: 179.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26APR-T0.9 ---
# Market Title: Will CPI rise more than 0.9% in April 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 50.00
#   Price: 0.0200¢, Quantity: 9.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 50.00
#   Price: 0.2600¢, Quantity: 1.00
#   Price: 0.2700¢, Quantity: 9.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26APR-T0.8 ---
# Market Title: Will CPI rise more than 0.8% in April 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 50.00
#   Price: 0.1700¢, Quantity: 281.00
#   Price: 0.1800¢, Quantity: 2.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 50.00
#   Price: 0.1300¢, Quantity: 7.00
#   Price: 0.1400¢, Quantity: 179.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26APR-T0.7 ---
# Market Title: Will CPI rise more than 0.7% in April 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 750.00
#   Price: 0.0200¢, Quantity: 700.00
#   Price: 0.0400¢, Quantity: 10.00
#   Price: 0.1000¢, Quantity: 1.00
#   Price: 0.2000¢, Quantity: 9.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 50.00
#   Price: 0.1000¢, Quantity: 134.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26APR-T0.6 ---
# Market Title: Will CPI rise more than 0.6% in April 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 50.00
#   Price: 0.3700¢, Quantity: 19.00
#   Price: 0.3800¢, Quantity: 14.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 50.00
#   Price: 0.0200¢, Quantity: 14.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAR-T1.3 ---
# Market Title: Will CPI rise more than 1.3% in March 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0300¢, Quantity: 10.00
#   Price: 0.0700¢, Quantity: 353.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 4500.00
#   Price: 0.0200¢, Quantity: 2900.00
#   Price: 0.0300¢, Quantity: 764.00
#   Price: 0.7100¢, Quantity: 93.00
#   Price: 0.7700¢, Quantity: 467.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAR-T1.2 ---
# Market Title: Will CPI rise more than 1.2% in March 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 62730.00
#   Price: 0.0200¢, Quantity: 658.00
#   Price: 0.0300¢, Quantity: 1911.00
#   Price: 0.0400¢, Quantity: 182.00
#   Price: 0.0500¢, Quantity: 853.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 4500.00
#   Price: 0.5000¢, Quantity: 9.00
#   Price: 0.6700¢, Quantity: 249.00
#   Price: 0.6800¢, Quantity: 382.00
#   Price: 0.6900¢, Quantity: 189.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAR-T1.1 ---
# Market Title: Will CPI rise more than 1.1% in March 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 100.00
#   Price: 0.0200¢, Quantity: 3800.00
#   Price: 0.0400¢, Quantity: 33.00
#   Price: 0.0500¢, Quantity: 11.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 3600.00
#   Price: 0.0200¢, Quantity: 2900.00
#   Price: 0.0300¢, Quantity: 200.00
#   Price: 0.1000¢, Quantity: 12500.00
#   Price: 0.3500¢, Quantity: 1.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAR-T1.0 ---
# Market Title: Will CPI rise more than 1.0% in March 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 16900.00
#   Price: 0.0200¢, Quantity: 4900.00
#   Price: 0.0300¢, Quantity: 3110.00
#   Price: 0.0400¢, Quantity: 1000.00
#   Price: 0.0500¢, Quantity: 868.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 8405.00
#   Price: 0.0200¢, Quantity: 2000.00
#   Price: 0.0300¢, Quantity: 1500.00
#   Price: 0.0400¢, Quantity: 1000.00
#   Price: 0.0500¢, Quantity: 800.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAR-T0.9 ---
# Market Title: Will CPI rise more than 0.9% in March 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 11900.00
#   Price: 0.0200¢, Quantity: 6900.00
#   Price: 0.0300¢, Quantity: 1910.00
#   Price: 0.0400¢, Quantity: 4000.00
#   Price: 0.0500¢, Quantity: 801.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 8405.00
#   Price: 0.0200¢, Quantity: 9900.00
#   Price: 0.0300¢, Quantity: 1900.00
#   Price: 0.0400¢, Quantity: 1000.00
#   Price: 0.0500¢, Quantity: 800.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAR-T0.8 ---
# Market Title: Will CPI rise more than 0.8% in March 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 13405.00
#   Price: 0.0200¢, Quantity: 4900.00
#   Price: 0.0300¢, Quantity: 1910.00
#   Price: 0.0400¢, Quantity: 1000.00
#   Price: 0.0500¢, Quantity: 802.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 8400.00
#   Price: 0.0200¢, Quantity: 4900.00
#   Price: 0.0300¢, Quantity: 1900.00
#   Price: 0.0400¢, Quantity: 1000.00
#   Price: 0.0500¢, Quantity: 800.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAR-T0.7 ---
# Market Title: Will CPI rise more than 0.7% in March 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 16900.00
#   Price: 0.0200¢, Quantity: 4860.00
#   Price: 0.0300¢, Quantity: 2210.00
#   Price: 0.0400¢, Quantity: 1000.00
#   Price: 0.0500¢, Quantity: 819.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 4608.00
#   Price: 0.0200¢, Quantity: 7137.00
#   Price: 0.0300¢, Quantity: 1554.00
#   Price: 0.0400¢, Quantity: 1000.00
#   Price: 0.0500¢, Quantity: 1747.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAR-T0.6 ---
# Market Title: Will CPI rise more than 0.6% in March 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 28400.00
#   Price: 0.0200¢, Quantity: 4900.00
#   Price: 0.0300¢, Quantity: 1510.00
#   Price: 0.0400¢, Quantity: 1000.00
#   Price: 0.0500¢, Quantity: 800.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 4750.00
#   Price: 0.0200¢, Quantity: 498.00
#   Price: 0.0300¢, Quantity: 1.00
#   Price: 0.0500¢, Quantity: 130.00
#   Price: 0.0600¢, Quantity: 60.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26NOV-T0.5 ---
# Market Title: Will CPI rise more than 0.5% in November 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0400¢, Quantity: 8.00
#   Price: 0.0500¢, Quantity: 1.00
#   Price: 0.0900¢, Quantity: 48.00
#   Price: 0.1000¢, Quantity: 40.00
#   Price: 0.1600¢, Quantity: 20.00
#
# NO BIDS:
#   Price: 0.0900¢, Quantity: 1.00
#   Price: 0.5600¢, Quantity: 4.00
#   Price: 0.6500¢, Quantity: 40.00
#   Price: 0.7200¢, Quantity: 200.00
#   Price: 0.7300¢, Quantity: 8.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26NOV-T0.4 ---
# Market Title: Will CPI rise more than 0.4% in November 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.2700¢, Quantity: 44.00
#   Price: 0.3100¢, Quantity: 218.00
#   Price: 0.3400¢, Quantity: 1.00
#
# NO BIDS:
#   Price: 0.2200¢, Quantity: 2.00
#   Price: 0.5300¢, Quantity: 41.00
#   Price: 0.5700¢, Quantity: 200.00
#   Price: 0.6000¢, Quantity: 3.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26NOV-T0.3 ---
# Market Title: Will CPI rise more than 0.3% in November 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.3600¢, Quantity: 41.00
#   Price: 0.4300¢, Quantity: 16.00
#   Price: 0.4400¢, Quantity: 212.00
#
# NO BIDS:
#   Price: 0.4100¢, Quantity: 42.00
#   Price: 0.4600¢, Quantity: 200.00
#   Price: 0.5000¢, Quantity: 3.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26NOV-T0.2 ---
# Market Title: Will CPI rise more than 0.2% in November 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.5300¢, Quantity: 42.00
#   Price: 0.5500¢, Quantity: 200.00
#   Price: 0.6000¢, Quantity: 13.00
#
# NO BIDS:
#   Price: 0.2700¢, Quantity: 40.00
#   Price: 0.3400¢, Quantity: 207.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26NOV-T0.1 ---
# Market Title: Will CPI rise more than 0.1% in November 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.6700¢, Quantity: 42.00
#   Price: 0.6900¢, Quantity: 200.00
#   Price: 0.7300¢, Quantity: 6.00
#   Price: 0.7400¢, Quantity: 6.00
#
# NO BIDS:
#   Price: 0.1500¢, Quantity: 45.00
#   Price: 0.2100¢, Quantity: 25.00
#   Price: 0.2200¢, Quantity: 200.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26NOV-T-0.1 ---
# Market Title: Will CPI rise more than -0.1% in November 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.7700¢, Quantity: 42.00
#   Price: 0.8300¢, Quantity: 200.00
#   Price: 0.8400¢, Quantity: 5.00
#
# NO BIDS:
#   Price: 0.0200¢, Quantity: 62.00
#   Price: 0.0500¢, Quantity: 10.00
#   Price: 0.0700¢, Quantity: 47.00
#   Price: 0.0800¢, Quantity: 201.00
#   Price: 0.0900¢, Quantity: 5.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26NOV-T0.0 ---
# Market Title: Will CPI rise more than 0.0% in November 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.7300¢, Quantity: 44.00
#   Price: 0.7900¢, Quantity: 216.00
#   Price: 0.8200¢, Quantity: 3.00
#
# NO BIDS:
#   Price: 0.0500¢, Quantity: 48.00
#   Price: 0.1000¢, Quantity: 200.00
#   Price: 0.1200¢, Quantity: 2.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26OCT-T0.5 ---
# Market Title: Will CPI rise more than 0.5% in October 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0900¢, Quantity: 41.00
#   Price: 0.1300¢, Quantity: 200.00
#   Price: 0.1500¢, Quantity: 5.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 1100.00
#   Price: 0.0200¢, Quantity: 1100.00
#   Price: 0.0300¢, Quantity: 100.00
#   Price: 0.6900¢, Quantity: 40.00
#   Price: 0.7600¢, Quantity: 200.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26OCT-T0.4 ---
# Market Title: Will CPI rise more than 0.4% in October 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.1800¢, Quantity: 41.00
#   Price: 0.2200¢, Quantity: 208.00
#   Price: 0.2500¢, Quantity: 6.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 1500.00
#   Price: 0.0200¢, Quantity: 1500.00
#   Price: 0.0300¢, Quantity: 100.00
#   Price: 0.3000¢, Quantity: 3.00
#   Price: 0.6100¢, Quantity: 41.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26OCT-T0.3 ---
# Market Title: Will CPI rise more than 0.3% in October 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.3100¢, Quantity: 41.00
#   Price: 0.3300¢, Quantity: 200.00
#   Price: 0.3800¢, Quantity: 8.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 2300.00
#   Price: 0.2800¢, Quantity: 14.00
#   Price: 0.3200¢, Quantity: 32.00
#   Price: 0.4900¢, Quantity: 41.00
#   Price: 0.5600¢, Quantity: 209.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26OCT-T0.2 ---
# Market Title: Will CPI rise more than 0.2% in October 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 2500.00
#   Price: 0.0200¢, Quantity: 2500.00
#   Price: 0.0300¢, Quantity: 200.00
#   Price: 0.4500¢, Quantity: 40.00
#   Price: 0.5000¢, Quantity: 200.00
#
# NO BIDS:
#   Price: 0.3200¢, Quantity: 40.00
#   Price: 0.3900¢, Quantity: 200.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26OCT-T0.1 ---
# Market Title: Will CPI rise more than 0.1% in October 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 1300.00
#   Price: 0.0200¢, Quantity: 1300.00
#   Price: 0.0300¢, Quantity: 100.00
#   Price: 0.5600¢, Quantity: 3.00
#   Price: 0.6300¢, Quantity: 50.00
#
# NO BIDS:
#   Price: 0.1400¢, Quantity: 40.00
#   Price: 0.2000¢, Quantity: 200.00
#   Price: 0.2100¢, Quantity: 3.00
#   Price: 0.2800¢, Quantity: 12.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26OCT-T-0.1 ---
# Market Title: Will CPI rise more than -0.1% in October 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 4400.00
#   Price: 0.0200¢, Quantity: 2900.00
#   Price: 0.0300¢, Quantity: 300.00
#   Price: 0.5400¢, Quantity: 14.00
#   Price: 0.5700¢, Quantity: 54.00
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-26OCT-T0.0 ---
# Market Title: Will CPI rise more than 0.0% in October 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 4300.00
#   Price: 0.0200¢, Quantity: 2900.00
#   Price: 0.0300¢, Quantity: 300.00
#   Price: 0.5600¢, Quantity: 7.00
#   Price: 0.7700¢, Quantity: 46.00
#
# NO BIDS:
#   Price: 0.0600¢, Quantity: 200.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26SEP-T0.5 ---
# Market Title: Will CPI rise more than 0.5% in September 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.1000¢, Quantity: 43.00
#   Price: 0.1600¢, Quantity: 200.00
#   Price: 0.1800¢, Quantity: 3.00
#
# NO BIDS:
#   Price: 0.6900¢, Quantity: 41.00
#   Price: 0.7300¢, Quantity: 200.00
#   Price: 0.7600¢, Quantity: 3.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26SEP-T0.4 ---
# Market Title: Will CPI rise more than 0.4% in September 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.1500¢, Quantity: 47.00
#   Price: 0.2000¢, Quantity: 35.00
#   Price: 0.2100¢, Quantity: 43.00
#   Price: 0.2600¢, Quantity: 200.00
#   Price: 0.2700¢, Quantity: 1.00
#
# NO BIDS:
#   Price: 0.6000¢, Quantity: 40.00
#   Price: 0.6700¢, Quantity: 208.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26SEP-T0.3 ---
# Market Title: Will CPI rise more than 0.3% in September 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.3800¢, Quantity: 3.00
#   Price: 0.4000¢, Quantity: 202.00
#   Price: 0.4400¢, Quantity: 3.00
#   Price: 0.4500¢, Quantity: 7.00
#   Price: 0.4600¢, Quantity: 10.00
#
# NO BIDS:
#   Price: 0.3900¢, Quantity: 15.00
#   Price: 0.4200¢, Quantity: 3.00
#   Price: 0.4800¢, Quantity: 41.00
#   Price: 0.5300¢, Quantity: 202.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26SEP-T0.2 ---
# Market Title: Will CPI rise more than 0.2% in September 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.4600¢, Quantity: 40.00
#   Price: 0.5100¢, Quantity: 200.00
#   Price: 0.5300¢, Quantity: 3.00
#   Price: 0.6000¢, Quantity: 13.00
#
# NO BIDS:
#   Price: 0.3100¢, Quantity: 40.00
#   Price: 0.3800¢, Quantity: 200.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26SEP-T0.1 ---
# Market Title: Will CPI rise more than 0.1% in September 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.5900¢, Quantity: 41.00
#   Price: 0.6600¢, Quantity: 207.00
#
# NO BIDS:
#   Price: 0.1700¢, Quantity: 41.00
#   Price: 0.2300¢, Quantity: 200.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26SEP-T-0.1 ---
# Market Title: Will CPI rise more than -0.1% in September 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.8200¢, Quantity: 44.00
#   Price: 0.8800¢, Quantity: 10.00
#   Price: 0.9100¢, Quantity: 203.00
#   Price: 0.9800¢, Quantity: 17.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 200.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26SEP-T0.0 ---
# Market Title: Will CPI rise more than 0.0% in September 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.7400¢, Quantity: 40.00
#   Price: 0.8100¢, Quantity: 200.00
#   Price: 0.8200¢, Quantity: 5.00
#
# NO BIDS:
#   Price: 0.0300¢, Quantity: 49.00
#   Price: 0.0800¢, Quantity: 200.00
#   Price: 0.1000¢, Quantity: 9.00
#   Price: 0.1100¢, Quantity: 5.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26AUG-T0.5 ---
# Market Title: Will CPI rise more than 0.5% in August 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0700¢, Quantity: 3.00
#   Price: 0.1100¢, Quantity: 43.00
#   Price: 0.1500¢, Quantity: 212.00
#   Price: 0.1700¢, Quantity: 1.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 900.00
#   Price: 0.0200¢, Quantity: 900.00
#   Price: 0.0300¢, Quantity: 100.00
#   Price: 0.1800¢, Quantity: 2.00
#   Price: 0.5600¢, Quantity: 3.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26AUG-T0.4 ---
# Market Title: Will CPI rise more than 0.4% in August 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.1400¢, Quantity: 59.00
#   Price: 0.1600¢, Quantity: 5.00
#   Price: 0.1900¢, Quantity: 71.00
#   Price: 0.2100¢, Quantity: 200.00
#   Price: 0.2300¢, Quantity: 1.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 1300.00
#   Price: 0.0200¢, Quantity: 1300.00
#   Price: 0.0300¢, Quantity: 100.00
#   Price: 0.6400¢, Quantity: 41.00
#   Price: 0.6800¢, Quantity: 200.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26AUG-T0.3 ---
# Market Title: Will CPI rise more than 0.3% in August 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.2400¢, Quantity: 40.00
#   Price: 0.3100¢, Quantity: 200.00
#   Price: 0.3300¢, Quantity: 3.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 1500.00
#   Price: 0.0200¢, Quantity: 1500.00
#   Price: 0.0300¢, Quantity: 100.00
#   Price: 0.4000¢, Quantity: 1.00
#   Price: 0.4600¢, Quantity: 16.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26AUG-T0.2 ---
# Market Title: Will CPI rise more than 0.2% in August 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 2000.00
#   Price: 0.0200¢, Quantity: 2000.00
#   Price: 0.0300¢, Quantity: 100.00
#   Price: 0.2100¢, Quantity: 3.00
#   Price: 0.2500¢, Quantity: 11.00
#
# NO BIDS:
#   Price: 0.3400¢, Quantity: 41.00
#   Price: 0.4100¢, Quantity: 200.00
#   Price: 0.4300¢, Quantity: 3.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26AUG-T0.1 ---
# Market Title: Will CPI rise more than 0.1% in August 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 2600.00
#   Price: 0.0200¢, Quantity: 2600.00
#   Price: 0.0300¢, Quantity: 200.00
#   Price: 0.6000¢, Quantity: 41.00
#   Price: 0.6600¢, Quantity: 200.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 2600.00
#   Price: 0.0200¢, Quantity: 2600.00
#   Price: 0.0300¢, Quantity: 200.00
#   Price: 0.2000¢, Quantity: 81.00
#   Price: 0.2500¢, Quantity: 200.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26AUG-T-0.1 ---
# Market Title: Will CPI rise more than -0.1% in August 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 4400.00
#   Price: 0.0200¢, Quantity: 2900.00
#   Price: 0.0300¢, Quantity: 300.00
#   Price: 0.8200¢, Quantity: 43.00
#   Price: 0.8900¢, Quantity: 215.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 204.00
#   Price: 0.0200¢, Quantity: 92.00
#   Price: 0.0300¢, Quantity: 84.00
#   Price: 0.0500¢, Quantity: 200.00
#   Price: 0.1000¢, Quantity: 174.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26AUG-T0.0 ---
# Market Title: Will CPI rise more than 0.0% in August 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 2000.00
#   Price: 0.0200¢, Quantity: 2000.00
#   Price: 0.0300¢, Quantity: 100.00
#   Price: 0.7600¢, Quantity: 40.00
#   Price: 0.8200¢, Quantity: 200.00
#
# NO BIDS:
#   Price: 0.0800¢, Quantity: 80.00
#   Price: 0.1200¢, Quantity: 200.00
#   Price: 0.1500¢, Quantity: 199.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26JUL-T0.5 ---
# Market Title: Will CPI rise more than 0.5% in July 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0600¢, Quantity: 40.00
#   Price: 0.1000¢, Quantity: 200.00
#   Price: 0.1300¢, Quantity: 2.00
#   Price: 0.2000¢, Quantity: 5.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 1000.00
#   Price: 0.0200¢, Quantity: 1000.00
#   Price: 0.0300¢, Quantity: 100.00
#   Price: 0.1800¢, Quantity: 2.00
#   Price: 0.7300¢, Quantity: 40.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26JUL-T0.4 ---
# Market Title: Will CPI rise more than 0.4% in July 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.1300¢, Quantity: 53.00
#   Price: 0.1500¢, Quantity: 59.00
#   Price: 0.1700¢, Quantity: 200.00
#   Price: 0.1900¢, Quantity: 3.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 1400.00
#   Price: 0.0200¢, Quantity: 1400.00
#   Price: 0.0300¢, Quantity: 100.00
#   Price: 0.6500¢, Quantity: 40.00
#   Price: 0.7200¢, Quantity: 200.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26JUL-T0.3 ---
# Market Title: Will CPI rise more than 0.3% in July 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.2900¢, Quantity: 46.00
#   Price: 0.3400¢, Quantity: 200.00
#   Price: 0.3500¢, Quantity: 6.00
#   Price: 0.3600¢, Quantity: 25.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 2500.00
#   Price: 0.0200¢, Quantity: 2500.00
#   Price: 0.0300¢, Quantity: 200.00
#   Price: 0.5200¢, Quantity: 40.00
#   Price: 0.5900¢, Quantity: 209.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26JUL-T0.2 ---
# Market Title: Will CPI rise more than 0.2% in July 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 2700.00
#   Price: 0.0200¢, Quantity: 2700.00
#   Price: 0.0300¢, Quantity: 200.00
#   Price: 0.4600¢, Quantity: 43.00
#   Price: 0.4800¢, Quantity: 200.00
#
# NO BIDS:
#   Price: 0.3400¢, Quantity: 41.00
#   Price: 0.4100¢, Quantity: 200.00
#   Price: 0.4200¢, Quantity: 3.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26JUL-T0.1 ---
# Market Title: Will CPI rise more than 0.1% in July 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 3900.00
#   Price: 0.0200¢, Quantity: 2900.00
#   Price: 0.0300¢, Quantity: 300.00
#   Price: 0.5600¢, Quantity: 3.00
#   Price: 0.6100¢, Quantity: 40.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 3900.00
#   Price: 0.0200¢, Quantity: 2900.00
#   Price: 0.0300¢, Quantity: 300.00
#   Price: 0.0500¢, Quantity: 61.00
#   Price: 0.0600¢, Quantity: 64.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26JUL-T-0.1 ---
# Market Title: Will CPI rise more than -0.1% in July 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 4100.00
#   Price: 0.0200¢, Quantity: 2900.00
#   Price: 0.0300¢, Quantity: 300.00
#   Price: 0.8200¢, Quantity: 42.00
#   Price: 0.8600¢, Quantity: 200.00
#
# NO BIDS:
#   Price: 0.0500¢, Quantity: 100.00
#   Price: 0.0600¢, Quantity: 200.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26JUL-T0.0 ---
# Market Title: Will CPI rise more than 0.0% in July 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 4400.00
#   Price: 0.0200¢, Quantity: 2900.00
#   Price: 0.0300¢, Quantity: 300.00
#   Price: 0.7400¢, Quantity: 41.00
#   Price: 0.8000¢, Quantity: 200.00
#
# NO BIDS:
#   Price: 0.0200¢, Quantity: 40.00
#   Price: 0.0900¢, Quantity: 200.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26JUN-T0.5 ---
# Market Title: Will CPI rise more than 0.5% in June 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.1500¢, Quantity: 42.00
#   Price: 0.1600¢, Quantity: 200.00
#   Price: 0.2200¢, Quantity: 10.00
#
# NO BIDS:
#   Price: 0.5000¢, Quantity: 3.00
#   Price: 0.6700¢, Quantity: 40.00
#   Price: 0.7400¢, Quantity: 200.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26JUN-T0.4 ---
# Market Title: Will CPI rise more than 0.4% in June 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.1400¢, Quantity: 51.00
#   Price: 0.1500¢, Quantity: 56.00
#   Price: 0.2000¢, Quantity: 200.00
#   Price: 0.2100¢, Quantity: 3.00
#   Price: 0.2800¢, Quantity: 15.00
#
# NO BIDS:
#   Price: 0.6200¢, Quantity: 40.00
#   Price: 0.6900¢, Quantity: 200.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26JUN-T0.3 ---
# Market Title: Will CPI rise more than 0.3% in June 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.3100¢, Quantity: 55.00
#   Price: 0.3700¢, Quantity: 74.00
#   Price: 0.3800¢, Quantity: 201.00
#   Price: 0.3900¢, Quantity: 5.00
#
# NO BIDS:
#   Price: 0.4800¢, Quantity: 40.00
#   Price: 0.5400¢, Quantity: 200.00
#   Price: 0.5500¢, Quantity: 5.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26JUN-T0.2 ---
# Market Title: Will CPI rise more than 0.2% in June 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.5000¢, Quantity: 41.00
#   Price: 0.5100¢, Quantity: 200.00
#   Price: 0.5700¢, Quantity: 4.00
#
# NO BIDS:
#   Price: 0.3200¢, Quantity: 41.00
#   Price: 0.3900¢, Quantity: 204.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26JUN-T0.1 ---
# Market Title: Will CPI rise more than 0.1% in June 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.5300¢, Quantity: 43.00
#   Price: 0.5800¢, Quantity: 200.00
#   Price: 0.5900¢, Quantity: 8.00
#   Price: 0.6000¢, Quantity: 5.00
#
# NO BIDS:
#   Price: 0.2500¢, Quantity: 120.00
#   Price: 0.3000¢, Quantity: 400.00
#   Price: 0.3200¢, Quantity: 200.00
#   Price: 0.3300¢, Quantity: 5.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26JUN-T-0.1 ---
# Market Title: Will CPI rise more than -0.1% in June 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.5000¢, Quantity: 3.00
#   Price: 0.6700¢, Quantity: 40.00
#   Price: 0.7500¢, Quantity: 200.00
#   Price: 0.7600¢, Quantity: 5.00
#
# NO BIDS:
#   Price: 0.0700¢, Quantity: 118.00
#   Price: 0.1400¢, Quantity: 200.00
#   Price: 0.1500¢, Quantity: 5.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26JUN-T0.0 ---
# Market Title: Will CPI rise more than 0.0% in June 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.6100¢, Quantity: 48.00
#   Price: 0.6900¢, Quantity: 200.00
#   Price: 0.7000¢, Quantity: 5.00
#
# NO BIDS:
#   Price: 0.1500¢, Quantity: 89.00
#   Price: 0.2100¢, Quantity: 245.00
#   Price: 0.2200¢, Quantity: 220.00
#   Price: 0.2300¢, Quantity: 5.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAY-T0.5 ---
# Market Title: Will CPI rise more than 0.5% in May 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.2400¢, Quantity: 1.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 1800.00
#   Price: 0.0200¢, Quantity: 1800.00
#   Price: 0.0300¢, Quantity: 266.00
#   Price: 0.5400¢, Quantity: 6.00
#   Price: 0.6000¢, Quantity: 1.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAY-T0.4 ---
# Market Title: Will CPI rise more than 0.4% in May 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 1419.00
#   Price: 0.0200¢, Quantity: 1414.00
#   Price: 0.0300¢, Quantity: 114.00
#   Price: 0.2000¢, Quantity: 40.00
#   Price: 0.2400¢, Quantity: 50.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 1400.00
#   Price: 0.0200¢, Quantity: 1400.00
#   Price: 0.0300¢, Quantity: 353.00
#   Price: 0.0400¢, Quantity: 19.00
#   Price: 0.0600¢, Quantity: 6.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAY-T0.3 ---
# Market Title: Will CPI rise more than 0.3% in May 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 2600.00
#   Price: 0.0200¢, Quantity: 2600.00
#   Price: 0.0300¢, Quantity: 200.00
#   Price: 0.0400¢, Quantity: 15.00
#   Price: 0.4000¢, Quantity: 16.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 2600.00
#   Price: 0.0200¢, Quantity: 2600.00
#   Price: 0.0300¢, Quantity: 266.00
#   Price: 0.0400¢, Quantity: 5.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAY-T0.2 ---
# Market Title: Will CPI rise more than 0.2% in May 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0400¢, Quantity: 5.00
#
# NO BIDS:
#   Price: 0.0500¢, Quantity: 1.00
#   Price: 0.0700¢, Quantity: 5.00
#   Price: 0.0800¢, Quantity: 136.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAY-T0.1 ---
# Market Title: Will CPI rise more than 0.1% in May 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 2600.00
#   Price: 0.0200¢, Quantity: 2600.00
#   Price: 0.0300¢, Quantity: 200.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 2600.00
#   Price: 0.0200¢, Quantity: 2600.00
#   Price: 0.0300¢, Quantity: 200.00
#   Price: 0.0500¢, Quantity: 1.00
#   Price: 0.0700¢, Quantity: 43.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAY-T-0.1 ---
# Market Title: Will CPI rise more than -0.1% in May 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 3700.00
#   Price: 0.0200¢, Quantity: 2900.00
#   Price: 0.0300¢, Quantity: 300.00
#   Price: 0.0400¢, Quantity: 5.00
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAY-T0.0 ---
# Market Title: Will CPI rise more than 0.0% in May 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 3100.00
#   Price: 0.0200¢, Quantity: 2900.00
#   Price: 0.0300¢, Quantity: 200.00
#   Price: 0.0400¢, Quantity: 5.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 3240.00
#   Price: 0.0200¢, Quantity: 2962.00
#   Price: 0.0300¢, Quantity: 200.00
#   Price: 0.1500¢, Quantity: 447.00
#   Price: 0.1600¢, Quantity: 5.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26APR-T0.5 ---
# Market Title: Will CPI rise more than 0.5% in April 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 4400.00
#   Price: 0.0200¢, Quantity: 2900.00
#   Price: 0.0300¢, Quantity: 600.00
#   Price: 0.1100¢, Quantity: 74.00
#   Price: 0.1200¢, Quantity: 74.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 30000.00
#   Price: 0.0300¢, Quantity: 3166.00
#   Price: 0.0400¢, Quantity: 196.00
#   Price: 0.0500¢, Quantity: 64.00
#   Price: 0.0600¢, Quantity: 88.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26APR-T0.4 ---
# Market Title: Will CPI rise more than 0.4% in April 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 4400.00
#   Price: 0.0200¢, Quantity: 2900.00
#   Price: 0.0300¢, Quantity: 500.00
#   Price: 0.2900¢, Quantity: 195.00
#   Price: 0.4600¢, Quantity: 50.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 20001.00
#   Price: 0.0500¢, Quantity: 162.00
#   Price: 0.0600¢, Quantity: 70.00
#   Price: 0.0700¢, Quantity: 100.00
#   Price: 0.0800¢, Quantity: 76.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26APR-T0.3 ---
# Market Title: Will CPI rise more than 0.3% in April 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 4400.00
#   Price: 0.0200¢, Quantity: 2900.00
#   Price: 0.0300¢, Quantity: 400.00
#   Price: 0.2500¢, Quantity: 150.00
#   Price: 0.7600¢, Quantity: 460.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 146.00
#   Price: 0.0200¢, Quantity: 132.00
#   Price: 0.0300¢, Quantity: 66.00
#   Price: 0.0600¢, Quantity: 1.00
#   Price: 0.1200¢, Quantity: 200.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26APR-T0.2 ---
# Market Title: Will CPI rise more than 0.2% in April 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 2300.00
#   Price: 0.0200¢, Quantity: 2300.00
#   Price: 0.0300¢, Quantity: 200.00
#   Price: 0.5300¢, Quantity: 150.00
#   Price: 0.5600¢, Quantity: 2.00
#
# NO BIDS:
#   Price: 0.0300¢, Quantity: 1.00
#   Price: 0.0700¢, Quantity: 221.00
#   Price: 0.0800¢, Quantity: 5.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26APR-T0.1 ---
# Market Title: Will CPI rise more than 0.1% in April 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   No YES bids available.
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 200.00
#   Price: 0.0200¢, Quantity: 1.00
#   Price: 0.0500¢, Quantity: 86.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26APR-T-0.1 ---
# Market Title: Will CPI rise more than -0.1% in April 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   No YES bids available.
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-26APR-T0.0 ---
# Market Title: Will CPI rise more than 0.0% in April 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   No YES bids available.
#
# NO BIDS:
#   Price: 0.0200¢, Quantity: 1.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAR-T0.5 ---
# Market Title: Will CPI rise more than 0.5% in March 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 4450.00
#   Price: 0.0200¢, Quantity: 2900.00
#   Price: 0.0300¢, Quantity: 700.00
#   Price: 0.0700¢, Quantity: 10000.00
#   Price: 0.0800¢, Quantity: 24.00
#
# NO BIDS:
#   Price: 0.0300¢, Quantity: 100.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAR-T0.4 ---
# Market Title: Will CPI rise more than 0.4% in March 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 1150.00
#   Price: 0.0200¢, Quantity: 1100.00
#   Price: 0.0300¢, Quantity: 100.00
#   Price: 0.0700¢, Quantity: 10000.00
#   Price: 0.2000¢, Quantity: 100.00
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAR-T0.3 ---
# Market Title: Will CPI rise more than 0.3% in March 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 4450.00
#   Price: 0.0200¢, Quantity: 2900.00
#   Price: 0.0300¢, Quantity: 700.00
#   Price: 0.0400¢, Quantity: 25000.00
#   Price: 0.3300¢, Quantity: 25.00
#
# NO BIDS:
#   Price: 0.0100¢, Quantity: 159.00
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAR-T0.2 ---
# Market Title: Will CPI rise more than 0.2% in March 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 6757.00
#   Price: 0.0200¢, Quantity: 2900.00
#   Price: 0.0300¢, Quantity: 700.00
#   Price: 0.0400¢, Quantity: 20000.00
#   Price: 0.1500¢, Quantity: 7500.00
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAR-T0.1 ---
# Market Title: Will CPI rise more than 0.1% in March 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 4400.00
#   Price: 0.0200¢, Quantity: 2900.00
#   Price: 0.0300¢, Quantity: 700.00
#   Price: 0.0500¢, Quantity: 30000.00
#   Price: 0.0600¢, Quantity: 10000.00
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAR-T-0.1 ---
# Market Title: Will CPI rise more than -0.1% in March 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 4450.00
#   Price: 0.0200¢, Quantity: 2900.00
#   Price: 0.0300¢, Quantity: 700.00
#   Price: 0.0500¢, Quantity: 25000.00
#   Price: 0.0700¢, Quantity: 100000.00
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-26MAR-T0.0 ---
# Market Title: Will CPI rise more than 0.0% in March 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   Price: 0.0100¢, Quantity: 4400.00
#   Price: 0.0200¢, Quantity: 2900.00
#   Price: 0.0300¢, Quantity: 700.00
#   Price: 0.0400¢, Quantity: 15000.00
#   Price: 0.0500¢, Quantity: 15000.00
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-26FEB-T0.4 ---
# Market Title: Will CPI rise more than 0.4% in February 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   No YES bids available.
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-26FEB-T0.3 ---
# Market Title: Will CPI rise more than 0.3% in February 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   No YES bids available.
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-26FEB-T0.2 ---
# Market Title: Will CPI rise more than 0.2% in February 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   No YES bids available.
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-26FEB-T0.1 ---
# Market Title: Will CPI rise more than 0.1% in February 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   No YES bids available.
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-26FEB-T-0.1 ---
# Market Title: Will CPI rise more than -0.1% in February 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   No YES bids available.
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-26FEB-T0.0 ---
# Market Title: Will CPI rise more than 0.0% in February 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   No YES bids available.
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-26JAN-T0.4 ---
# Market Title: Will CPI rise more than 0.4% in January 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   No YES bids available.
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-26JAN-T0.3 ---
# Market Title: Will CPI rise more than 0.3% in January 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   No YES bids available.
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-26JAN-T0.2 ---
# Market Title: Will CPI rise more than 0.2% in January 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   No YES bids available.
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-26JAN-T0.1 ---
# Market Title: Will CPI rise more than 0.1% in January 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   No YES bids available.
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-26JAN-T-0.1 ---
# Market Title: Will CPI rise more than -0.1% in January 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   No YES bids available.
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-26JAN-T0.0 ---
# Market Title: Will CPI rise more than 0.0% in January 2026?
# Expected CPI Core: N/A%
# YES BIDS:
#   No YES bids available.
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-25DEC-T0.4 ---
# Market Title: Will CPI rise more than 0.4% in December 2025?
# Expected CPI Core: N/A%
# YES BIDS:
#   No YES bids available.
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-25DEC-T0.3 ---
# Market Title: Will CPI rise more than 0.3% in December 2025?
# Expected CPI Core: N/A%
# YES BIDS:
#   No YES bids available.
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-25DEC-T0.2 ---
# Market Title: Will CPI rise more than 0.2% in December 2025?
# Expected CPI Core: N/A%
# YES BIDS:
#   No YES bids available.
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-25DEC-T0.1 ---
# Market Title: Will CPI rise more than 0.1% in December 2025?
# Expected CPI Core: N/A%
# YES BIDS:
#   No YES bids available.
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-25DEC-T-0.1 ---
# Market Title: Will CPI rise more than -0.1% in December 2025?
# Expected CPI Core: N/A%
# YES BIDS:
#   No YES bids available.
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-25DEC-T0.0 ---
# Market Title: Will CPI rise more than 0.0% in December 2025?
# Expected CPI Core: N/A%
# YES BIDS:
#   No YES bids available.
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------
#
# --- Orderbook for KXCPI-25OCT-T0.4 ---
# Market Title: Will CPI rise more than 0.4% in October 2025?
# Expected CPI Core: N/A%
# YES BIDS:
#   No YES bids available.
#
# NO BIDS:
#   No NO bids available.
# -------------------------------------

# %%
import requests
from datetime import datetime, UTC

# Get historical markets for the KXCPI series with 'settled' status
# We'll use a max_settle_time of today to get all markets settled up to now.
current_time_utc = datetime.now(UTC).isoformat() # Using timezone-aware object for UTC

historical_markets_url_base = "https://api.elections.kalshi.com/trade-api/v2/historical/markets/"
historical_markets_url = f"{historical_markets_url_base}KXCPI"
historical_markets_response = requests.get(historical_markets_url)

# Print the raw response text to debug the JSONDecodeError
print("Raw API Response:")
print(historical_markets_response.text)

try:
    historical_markets_data = historical_markets_response.json()

    print(f"\nHistorical Settled Markets in KXCPI series:")

    if 'markets' in historical_markets_data and historical_markets_data['markets']:
        print("List of Inflation/CPI-related Tickers and their details:")
        for market in historical_markets_data['markets']:
            print(f"  - Ticker: {market['ticker']}")
            print(f"    Title: {market['title']}")
            print(f"    Event: {market['event_ticker']}")
            print(f"    Close Time: {market.get('close_time', 'N/A')}")
            print(f"    Settlement Price: {market.get('settlement_price', 'N/A')}¢")
            print(f"    Settlement Value: {market.get('settlement_value', 'N/A')}")
            print()
    else:
        print("No historical settled markets found for the KXCPI series.")
except requests.exceptions.JSONDecodeError as e:
    print(f"Error decoding JSON: {e}")
    print("Could not parse the API response as JSON. The raw response is printed above.")
# Out:
# Raw API Response:
# {"error":{"code":"failed_to_get_market_by_ticker:_not_found","message":"failed to get market by ticker: not found","service":"query-exchange"}}
#
# Historical Settled Markets in KXCPI series:
# No historical settled markets found for the KXCPI series.

# %%
import requests

# Get all active markets from Kalshi API for the KXCPI series
markets_url = "https://api.elections.kalshi.com/trade-api/v2/markets?series_ticker=KXCPI"
markets_response = requests.get(markets_url)
markets_data = markets_response.json()

print(f"\nList of active markets in the KXCPI series:")
if 'markets' in markets_data and markets_data['markets']:
    for market in markets_data['markets']:
        print(f"- Ticker: {market['ticker']}")
        print(f"  Title: {market['title']}")
        print(f"  Event: {market['event_ticker']}")
        print()
else:
    print("No active markets found for the KXCPI series or an error occurred while fetching data.")
# Out:
# List of active markets in the KXCPI series:
# - Ticker: KXCPI-26MAY-T1.0
#   Title: Will CPI rise more than 1.0% in May 2026?
#   Event: KXCPI-26MAY
#
# - Ticker: KXCPI-26MAY-T0.9
#   Title: Will CPI rise more than 0.9% in May 2026?
#   Event: KXCPI-26MAY
#
# - Ticker: KXCPI-26MAY-T0.8
#   Title: Will CPI rise more than 0.8% in May 2026?
#   Event: KXCPI-26MAY
#
# - Ticker: KXCPI-26MAY-T0.7
#   Title: Will CPI rise more than 0.7% in May 2026?
#   Event: KXCPI-26MAY
#
# - Ticker: KXCPI-26MAY-T0.6
#   Title: Will CPI rise more than 0.6% in May 2026?
#   Event: KXCPI-26MAY
#
# - Ticker: KXCPI-26APR-T1.0
#   Title: Will CPI rise more than 1.0% in April 2026?
#   Event: KXCPI-26APR
#
# - Ticker: KXCPI-26APR-T0.9
#   Title: Will CPI rise more than 0.9% in April 2026?
#   Event: KXCPI-26APR
#
# - Ticker: KXCPI-26APR-T0.8
#   Title: Will CPI rise more than 0.8% in April 2026?
#   Event: KXCPI-26APR
#
# - Ticker: KXCPI-26APR-T0.7
#   Title: Will CPI rise more than 0.7% in April 2026?
#   Event: KXCPI-26APR
#
# - Ticker: KXCPI-26APR-T0.6
#   Title: Will CPI rise more than 0.6% in April 2026?
#   Event: KXCPI-26APR
#
# - Ticker: KXCPI-26MAR-T1.3
#   Title: Will CPI rise more than 1.3% in March 2026?
#   Event: KXCPI-26MAR
#
# - Ticker: KXCPI-26MAR-T1.2
#   Title: Will CPI rise more than 1.2% in March 2026?
#   Event: KXCPI-26MAR
#
# - Ticker: KXCPI-26MAR-T1.1
#   Title: Will CPI rise more than 1.1% in March 2026?
#   Event: KXCPI-26MAR
#
# - Ticker: KXCPI-26MAR-T1.0
#   Title: Will CPI rise more than 1.0% in March 2026?
#   Event: KXCPI-26MAR
#
# - Ticker: KXCPI-26MAR-T0.9
#   Title: Will CPI rise more than 0.9% in March 2026?
#   Event: KXCPI-26MAR
#
# - Ticker: KXCPI-26MAR-T0.8
#   Title: Will CPI rise more than 0.8% in March 2026?
#   Event: KXCPI-26MAR
#
# - Ticker: KXCPI-26MAR-T0.7
#   Title: Will CPI rise more than 0.7% in March 2026?
#   Event: KXCPI-26MAR
#
# - Ticker: KXCPI-26MAR-T0.6
#   Title: Will CPI rise more than 0.6% in March 2026?
#   Event: KXCPI-26MAR
#
# - Ticker: KXCPI-26NOV-T0.5
#   Title: Will CPI rise more than 0.5% in November 2026?
#   Event: KXCPI-26NOV
#
# - Ticker: KXCPI-26NOV-T0.4
#   Title: Will CPI rise more than 0.4% in November 2026?
#   Event: KXCPI-26NOV
#
# - Ticker: KXCPI-26NOV-T0.3
#   Title: Will CPI rise more than 0.3% in November 2026?
#   Event: KXCPI-26NOV
#
# - Ticker: KXCPI-26NOV-T0.2
#   Title: Will CPI rise more than 0.2% in November 2026?
#   Event: KXCPI-26NOV
#
# - Ticker: KXCPI-26NOV-T0.1
#   Title: Will CPI rise more than 0.1% in November 2026?
#   Event: KXCPI-26NOV
#
# - Ticker: KXCPI-26NOV-T-0.1
#   Title: Will CPI rise more than -0.1% in November 2026?
#   Event: KXCPI-26NOV
#
# - Ticker: KXCPI-26NOV-T0.0
#   Title: Will CPI rise more than 0.0% in November 2026?
#   Event: KXCPI-26NOV
#
# - Ticker: KXCPI-26OCT-T0.5
#   Title: Will CPI rise more than 0.5% in October 2026?
#   Event: KXCPI-26OCT
#
# - Ticker: KXCPI-26OCT-T0.4
#   Title: Will CPI rise more than 0.4% in October 2026?
#   Event: KXCPI-26OCT
#
# - Ticker: KXCPI-26OCT-T0.3
#   Title: Will CPI rise more than 0.3% in October 2026?
#   Event: KXCPI-26OCT
#
# - Ticker: KXCPI-26OCT-T0.2
#   Title: Will CPI rise more than 0.2% in October 2026?
#   Event: KXCPI-26OCT
#
# - Ticker: KXCPI-26OCT-T0.1
#   Title: Will CPI rise more than 0.1% in October 2026?
#   Event: KXCPI-26OCT
#
# - Ticker: KXCPI-26OCT-T-0.1
#   Title: Will CPI rise more than -0.1% in October 2026?
#   Event: KXCPI-26OCT
#
# - Ticker: KXCPI-26OCT-T0.0
#   Title: Will CPI rise more than 0.0% in October 2026?
#   Event: KXCPI-26OCT
#
# - Ticker: KXCPI-26SEP-T0.5
#   Title: Will CPI rise more than 0.5% in September 2026?
#   Event: KXCPI-26SEP
#
# - Ticker: KXCPI-26SEP-T0.4
#   Title: Will CPI rise more than 0.4% in September 2026?
#   Event: KXCPI-26SEP
#
# - Ticker: KXCPI-26SEP-T0.3
#   Title: Will CPI rise more than 0.3% in September 2026?
#   Event: KXCPI-26SEP
#
# - Ticker: KXCPI-26SEP-T0.2
#   Title: Will CPI rise more than 0.2% in September 2026?
#   Event: KXCPI-26SEP
#
# - Ticker: KXCPI-26SEP-T0.1
#   Title: Will CPI rise more than 0.1% in September 2026?
#   Event: KXCPI-26SEP
#
# - Ticker: KXCPI-26SEP-T-0.1
#   Title: Will CPI rise more than -0.1% in September 2026?
#   Event: KXCPI-26SEP
#
# - Ticker: KXCPI-26SEP-T0.0
#   Title: Will CPI rise more than 0.0% in September 2026?
#   Event: KXCPI-26SEP
#
# - Ticker: KXCPI-26AUG-T0.5
#   Title: Will CPI rise more than 0.5% in August 2026?
#   Event: KXCPI-26AUG
#
# - Ticker: KXCPI-26AUG-T0.4
#   Title: Will CPI rise more than 0.4% in August 2026?
#   Event: KXCPI-26AUG
#
# - Ticker: KXCPI-26AUG-T0.3
#   Title: Will CPI rise more than 0.3% in August 2026?
#   Event: KXCPI-26AUG
#
# - Ticker: KXCPI-26AUG-T0.2
#   Title: Will CPI rise more than 0.2% in August 2026?
#   Event: KXCPI-26AUG
#
# - Ticker: KXCPI-26AUG-T0.1
#   Title: Will CPI rise more than 0.1% in August 2026?
#   Event: KXCPI-26AUG
#
# - Ticker: KXCPI-26AUG-T-0.1
#   Title: Will CPI rise more than -0.1% in August 2026?
#   Event: KXCPI-26AUG
#
# - Ticker: KXCPI-26AUG-T0.0
#   Title: Will CPI rise more than 0.0% in August 2026?
#   Event: KXCPI-26AUG
#
# - Ticker: KXCPI-26JUL-T0.5
#   Title: Will CPI rise more than 0.5% in July 2026?
#   Event: KXCPI-26JUL
#
# - Ticker: KXCPI-26JUL-T0.4
#   Title: Will CPI rise more than 0.4% in July 2026?
#   Event: KXCPI-26JUL
#
# - Ticker: KXCPI-26JUL-T0.3
#   Title: Will CPI rise more than 0.3% in July 2026?
#   Event: KXCPI-26JUL
#
# - Ticker: KXCPI-26JUL-T0.2
#   Title: Will CPI rise more than 0.2% in July 2026?
#   Event: KXCPI-26JUL
#
# - Ticker: KXCPI-26JUL-T0.1
#   Title: Will CPI rise more than 0.1% in July 2026?
#   Event: KXCPI-26JUL
#
# - Ticker: KXCPI-26JUL-T-0.1
#   Title: Will CPI rise more than -0.1% in July 2026?
#   Event: KXCPI-26JUL
#
# - Ticker: KXCPI-26JUL-T0.0
#   Title: Will CPI rise more than 0.0% in July 2026?
#   Event: KXCPI-26JUL
#
# - Ticker: KXCPI-26JUN-T0.5
#   Title: Will CPI rise more than 0.5% in June 2026?
#   Event: KXCPI-26JUN
#
# - Ticker: KXCPI-26JUN-T0.4
#   Title: Will CPI rise more than 0.4% in June 2026?
#   Event: KXCPI-26JUN
#
# - Ticker: KXCPI-26JUN-T0.3
#   Title: Will CPI rise more than 0.3% in June 2026?
#   Event: KXCPI-26JUN
#
# - Ticker: KXCPI-26JUN-T0.2
#   Title: Will CPI rise more than 0.2% in June 2026?
#   Event: KXCPI-26JUN
#
# - Ticker: KXCPI-26JUN-T0.1
#   Title: Will CPI rise more than 0.1% in June 2026?
#   Event: KXCPI-26JUN
#
# - Ticker: KXCPI-26JUN-T-0.1
#   Title: Will CPI rise more than -0.1% in June 2026?
#   Event: KXCPI-26JUN
#
# - Ticker: KXCPI-26JUN-T0.0
#   Title: Will CPI rise more than 0.0% in June 2026?
#   Event: KXCPI-26JUN
#
# - Ticker: KXCPI-26MAY-T0.5
#   Title: Will CPI rise more than 0.5% in May 2026?
#   Event: KXCPI-26MAY
#
# - Ticker: KXCPI-26MAY-T0.4
#   Title: Will CPI rise more than 0.4% in May 2026?
#   Event: KXCPI-26MAY
#
# - Ticker: KXCPI-26MAY-T0.3
#   Title: Will CPI rise more than 0.3% in May 2026?
#   Event: KXCPI-26MAY
#
# - Ticker: KXCPI-26MAY-T0.2
#   Title: Will CPI rise more than 0.2% in May 2026?
#   Event: KXCPI-26MAY
#
# - Ticker: KXCPI-26MAY-T0.1
#   Title: Will CPI rise more than 0.1% in May 2026?
#   Event: KXCPI-26MAY
#
# - Ticker: KXCPI-26MAY-T-0.1
#   Title: Will CPI rise more than -0.1% in May 2026?
#   Event: KXCPI-26MAY
#
# - Ticker: KXCPI-26MAY-T0.0
#   Title: Will CPI rise more than 0.0% in May 2026?
#   Event: KXCPI-26MAY
#
# - Ticker: KXCPI-26APR-T0.5
#   Title: Will CPI rise more than 0.5% in April 2026?
#   Event: KXCPI-26APR
#
# - Ticker: KXCPI-26APR-T0.4
#   Title: Will CPI rise more than 0.4% in April 2026?
#   Event: KXCPI-26APR
#
# - Ticker: KXCPI-26APR-T0.3
#   Title: Will CPI rise more than 0.3% in April 2026?
#   Event: KXCPI-26APR
#
# - Ticker: KXCPI-26APR-T0.2
#   Title: Will CPI rise more than 0.2% in April 2026?
#   Event: KXCPI-26APR
#
# - Ticker: KXCPI-26APR-T0.1
#   Title: Will CPI rise more than 0.1% in April 2026?
#   Event: KXCPI-26APR
#
# - Ticker: KXCPI-26APR-T-0.1
#   Title: Will CPI rise more than -0.1% in April 2026?
#   Event: KXCPI-26APR
#
# - Ticker: KXCPI-26APR-T0.0
#   Title: Will CPI rise more than 0.0% in April 2026?
#   Event: KXCPI-26APR
#
# - Ticker: KXCPI-26MAR-T0.5
#   Title: Will CPI rise more than 0.5% in March 2026?
#   Event: KXCPI-26MAR
#
# - Ticker: KXCPI-26MAR-T0.4
#   Title: Will CPI rise more than 0.4% in March 2026?
#   Event: KXCPI-26MAR
#
# - Ticker: KXCPI-26MAR-T0.3
#   Title: Will CPI rise more than 0.3% in March 2026?
#   Event: KXCPI-26MAR
#
# - Ticker: KXCPI-26MAR-T0.2
#   Title: Will CPI rise more than 0.2% in March 2026?
#   Event: KXCPI-26MAR
#
# - Ticker: KXCPI-26MAR-T0.1
#   Title: Will CPI rise more than 0.1% in March 2026?
#   Event: KXCPI-26MAR
#
# - Ticker: KXCPI-26MAR-T-0.1
#   Title: Will CPI rise more than -0.1% in March 2026?
#   Event: KXCPI-26MAR
#
# - Ticker: KXCPI-26MAR-T0.0
#   Title: Will CPI rise more than 0.0% in March 2026?
#   Event: KXCPI-26MAR
#
# - Ticker: KXCPI-26FEB-T0.4
#   Title: Will CPI rise more than 0.4% in February 2026?
#   Event: KXCPI-26FEB
#
# - Ticker: KXCPI-26FEB-T0.3
#   Title: Will CPI rise more than 0.3% in February 2026?
#   Event: KXCPI-26FEB
#
# - Ticker: KXCPI-26FEB-T0.2
#   Title: Will CPI rise more than 0.2% in February 2026?
#   Event: KXCPI-26FEB
#
# - Ticker: KXCPI-26FEB-T0.1
#   Title: Will CPI rise more than 0.1% in February 2026?
#   Event: KXCPI-26FEB
#
# - Ticker: KXCPI-26FEB-T-0.1
#   Title: Will CPI rise more than -0.1% in February 2026?
#   Event: KXCPI-26FEB
#
# - Ticker: KXCPI-26FEB-T0.0
#   Title: Will CPI rise more than 0.0% in February 2026?
#   Event: KXCPI-26FEB
#
# - Ticker: KXCPI-26JAN-T0.4
#   Title: Will CPI rise more than 0.4% in January 2026?
#   Event: KXCPI-26JAN
#
# - Ticker: KXCPI-26JAN-T0.3
#   Title: Will CPI rise more than 0.3% in January 2026?
#   Event: KXCPI-26JAN
#
# - Ticker: KXCPI-26JAN-T0.2
#   Title: Will CPI rise more than 0.2% in January 2026?
#   Event: KXCPI-26JAN
#
# - Ticker: KXCPI-26JAN-T0.1
#   Title: Will CPI rise more than 0.1% in January 2026?
#   Event: KXCPI-26JAN
#
# - Ticker: KXCPI-26JAN-T-0.1
#   Title: Will CPI rise more than -0.1% in January 2026?
#   Event: KXCPI-26JAN
#
# - Ticker: KXCPI-26JAN-T0.0
#   Title: Will CPI rise more than 0.0% in January 2026?
#   Event: KXCPI-26JAN
#
# - Ticker: KXCPI-25DEC-T0.4
#   Title: Will CPI rise more than 0.4% in December 2025?
#   Event: KXCPI-25DEC
#
# - Ticker: KXCPI-25DEC-T0.3
#   Title: Will CPI rise more than 0.3% in December 2025?
#   Event: KXCPI-25DEC
#
# - Ticker: KXCPI-25DEC-T0.2
#   Title: Will CPI rise more than 0.2% in December 2025?
#   Event: KXCPI-25DEC
#
# - Ticker: KXCPI-25DEC-T0.1
#   Title: Will CPI rise more than 0.1% in December 2025?
#   Event: KXCPI-25DEC
#
# - Ticker: KXCPI-25DEC-T-0.1
#   Title: Will CPI rise more than -0.1% in December 2025?
#   Event: KXCPI-25DEC
#
# - Ticker: KXCPI-25DEC-T0.0
#   Title: Will CPI rise more than 0.0% in December 2025?
#   Event: KXCPI-25DEC
#
# - Ticker: KXCPI-25OCT-T0.4
#   Title: Will CPI rise more than 0.4% in October 2025?
#   Event: KXCPI-25OCT

# %%
import requests

# 1. Get all active markets for the KXCPI series to obtain individual market tickers
markets_url = "https://api.elections.kalshi.com/trade-api/v2/markets?series_ticker=KXCPI"
markets_response = requests.get(markets_url)
markets_data = markets_response.json()

print("\n--- Actieve KXCPI markten ophalen voor individuele historische aanroepen ---")
if 'markets' in markets_data and markets_data['markets']:
    kxcpi_market_tickers = [market['ticker'] for market in markets_data['markets']]
    print(f"{len(kxcpi_market_tickers)} actieve KXCPI markten gevonden. Nu individuele historische data ophalen...")

    historical_markets_url_base = "https://api.elections.kalshi.com/trade-api/v2/historical/markets/"

    print("\n--- Historische data voor individuele KXCPI markten --- ")
    for ticker in kxcpi_market_tickers:
        individual_historical_url = f"{historical_markets_url_base}{ticker}"
        individual_historical_response = requests.get(individual_historical_url)

        # Check if the request was successful and if there's content to parse
        if individual_historical_response.status_code == 200 and individual_historical_response.text:
            try:
                individual_historical_data = individual_historical_response.json()
                if 'market' in individual_historical_data:
                    market_info = individual_historical_data['market']
                    print(f"  - Ticker: {market_info.get('ticker', 'N/A')}")
                    print(f"    Title: {market_info.get('title', 'N/A')}")
                    # You could add more fields here if needed, e.g., print(f"    Status: {market_info.get('status', 'N/A')}")
                else:
                    print(f"  Geen market details gevonden voor ticker {ticker} in historische response.")
            except requests.exceptions.JSONDecodeError:
                print(f"  Fout bij decoderen van JSON voor historische data van {ticker}. Ruwe respons: {individual_historical_response.text[:200]}...")
        elif individual_historical_response.status_code == 404:
            print(f"  Historische data voor ticker {ticker} niet gevonden (404 Not Found).")
        else:
            print(f"  Fout bij het ophalen van historische data voor ticker {ticker}. Statuscode: {individual_historical_response.status_code}")
            print(f"  Ruwe respons: {individual_historical_response.text[:200]}...")

else:
    print("Geen actieve markten gevonden voor de KXCPI-serie.")
# Out:
# --- Actieve KXCPI markten ophalen voor individuele historische aanroepen ---
# 100 actieve KXCPI markten gevonden. Nu individuele historische data ophalen...
#
# --- Historische data voor individuele KXCPI markten ---
#   Historische data voor ticker KXCPI-26MAY-T1.0 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAY-T0.9 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAY-T0.8 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAY-T0.7 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAY-T0.6 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26APR-T1.0 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26APR-T0.9 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26APR-T0.8 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26APR-T0.7 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26APR-T0.6 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAR-T1.3 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAR-T1.2 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAR-T1.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAR-T1.0 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAR-T0.9 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAR-T0.8 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAR-T0.7 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAR-T0.6 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26NOV-T0.5 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26NOV-T0.4 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26NOV-T0.3 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26NOV-T0.2 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26NOV-T0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26NOV-T-0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26NOV-T0.0 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26OCT-T0.5 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26OCT-T0.4 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26OCT-T0.3 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26OCT-T0.2 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26OCT-T0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26OCT-T-0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26OCT-T0.0 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26SEP-T0.5 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26SEP-T0.4 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26SEP-T0.3 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26SEP-T0.2 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26SEP-T0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26SEP-T-0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26SEP-T0.0 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26AUG-T0.5 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26AUG-T0.4 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26AUG-T0.3 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26AUG-T0.2 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26AUG-T0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26AUG-T-0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26AUG-T0.0 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26JUL-T0.5 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26JUL-T0.4 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26JUL-T0.3 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26JUL-T0.2 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26JUL-T0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26JUL-T-0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26JUL-T0.0 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26JUN-T0.5 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26JUN-T0.4 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26JUN-T0.3 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26JUN-T0.2 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26JUN-T0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26JUN-T-0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26JUN-T0.0 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAY-T0.5 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAY-T0.4 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAY-T0.3 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAY-T0.2 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAY-T0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAY-T-0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAY-T0.0 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26APR-T0.5 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26APR-T0.4 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26APR-T0.3 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26APR-T0.2 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26APR-T0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26APR-T-0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26APR-T0.0 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAR-T0.5 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAR-T0.4 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAR-T0.3 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAR-T0.2 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAR-T0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAR-T-0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26MAR-T0.0 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26FEB-T0.4 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26FEB-T0.3 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26FEB-T0.2 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26FEB-T0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26FEB-T-0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26FEB-T0.0 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26JAN-T0.4 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26JAN-T0.3 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26JAN-T0.2 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26JAN-T0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26JAN-T-0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-26JAN-T0.0 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-25DEC-T0.4 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-25DEC-T0.3 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-25DEC-T0.2 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-25DEC-T0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-25DEC-T-0.1 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-25DEC-T0.0 niet gevonden (404 Not Found).
#   Historische data voor ticker KXCPI-25OCT-T0.4 niet gevonden (404 Not Found).
